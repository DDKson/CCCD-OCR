# %%
# %cd /content/drive/MyDrive/CCCD PROJECT
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# /content/drive/MyDrive/CCCD PROJECT
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
! pip install -q supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 1.9 MB/s eta 0:00:00

# %%
# %cd /content/drive/MyDrive/CCCD PROJECT/ultralytics
# !pip install --quiet -e .
from ultralytics import YOLO
# Out:
# /content/drive/MyDrive/CCCD PROJECT/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 97.6MB/s]

# %%
model.train(data="/content/drive/MyDrive/CCCD PROJECT/mydataset.yaml", mosaic = 0, epochs = 30, imgsz = 640)
# Out:
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import cv2
import supervision as sv

# %%
model = YOLO("/content/drive/MyDrive/CCCD PROJECT/ultralytics/runs/detect/train/weights/best.pt")

# %%
frame = cv2.imread("/content/Screenshot 2024-04-15 104231.png")
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
results = model.predict(frame, conf = 0.5)[0]
box_annotator = sv.BoundingBoxAnnotator()
detections = sv.Detections.from_ultralytics(results)

annotated_frame = box_annotator.annotate(
    frame.copy(), detections=detections)
# Out:
# 0: 416x640 1 ID, 2 Names, 1 Dob, 1 Sex, 2 Nats, 6 Hometowns, 2 Does, 14 Addresss, 203.8ms
# Speed: 5.1ms preprocess, 203.8ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)

# %%
results.plot()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
